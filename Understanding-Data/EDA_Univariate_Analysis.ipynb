# %% [markdown]
# <a href="https://colab.research.google.com/github/imtufail/Machine-Learning-Contents/blob/main/Understanding-Data/EDA_Univariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('EVSE-B-PowerCombined.csv')

# %%
df.sample(10)
# Out:
#                     time  shunt_voltage  bus_voltage_V  current_mA  power_mW  \
# 90382    12/25/2023 0:48            475          5.201         506      2500
# 110158  12/30/2023 10:22            566          5.193         620      3440
# 36846   12/26/2023 15:50            525          5.197         540      3140
# 108837  12/30/2023 10:00            614          5.189         614      3300
# 28853   12/25/2023 17:27            461          5.197         464      2420
# 32684   12/25/2023 18:33            466          5.201         462      2400
# 86580   12/24/2023 23:42            465          5.201         468      2420
# 12214    12/26/2023 2:05            870          5.169         930      5180
# 44372   12/26/2023 18:01            868          5.165         952      4920
# 73500   12/24/2023 19:57            462          5.197         506      2400
#
#            State         Attack Attack-Group   Label interface
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115298 entries, 0 to 115297
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   time           115298 non-null  object
#  1   shunt_voltage  115298 non-null  int64
#  2   bus_voltage_V  115298 non-null  float64
#  3   current_mA     115298 non-null  int64
#  4   power_mW       115298 non-null  int64
#  5   State          115298 non-null  object
#  6   Attack         115298 non-null  object
#  7   Attack-Group   115298 non-null  object
#  8   Label          115298 non-null  object
#  9   interface      115298 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 8.8+ MB

# %%
sns.countplot(df['Attack'])
# Out:
# <Axes: xlabel='count', ylabel='Attack'>

# %%
sns.countplot(data=df,x= df['Attack'])
# Out:
# <Axes: xlabel='Attack', ylabel='count'>

# %%
df['Attack'].value_counts()
# Out:
# Attack
# vuln-scan        26246
# tcp-flood        21367
# Backdoor         21137
# none             14363
# syn-flood        13517
# cryptojacking    11596
# syn-stealth       7072
# Name: count, dtype: int64
