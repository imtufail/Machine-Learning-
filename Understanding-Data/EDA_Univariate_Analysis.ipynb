# %% [markdown]
# <a href="https://colab.research.google.com/github/imtufail/Machine-Learning-Contents/blob/main/Understanding-Data/EDA_Univariate_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('EVSE-B-PowerCombined.csv')

# %%
df.sample(10)
# Out:
#                     time  shunt_voltage  bus_voltage_V  current_mA  power_mW  \
# 90382    12/25/2023 0:48            475          5.201         506      2500
# 110158  12/30/2023 10:22            566          5.193         620      3440
# 36846   12/26/2023 15:50            525          5.197         540      3140
# 108837  12/30/2023 10:00            614          5.189         614      3300
# 28853   12/25/2023 17:27            461          5.197         464      2420
# 32684   12/25/2023 18:33            466          5.201         462      2400
# 86580   12/24/2023 23:42            465          5.201         468      2420
# 12214    12/26/2023 2:05            870          5.169         930      5180
# 44372   12/26/2023 18:01            868          5.165         952      4920
# 73500   12/24/2023 19:57            462          5.197         506      2400
#
#            State         Attack Attack-Group   Label interface
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115298 entries, 0 to 115297
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   time           115298 non-null  object
#  1   shunt_voltage  115298 non-null  int64
#  2   bus_voltage_V  115298 non-null  float64
#  3   current_mA     115298 non-null  int64
#  4   power_mW       115298 non-null  int64
#  5   State          115298 non-null  object
#  6   Attack         115298 non-null  object
#  7   Attack-Group   115298 non-null  object
#  8   Label          115298 non-null  object
#  9   interface      115298 non-null  object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 8.8+ MB

# %%
sns.countplot(df['Attack'])
# Out:
# <Axes: xlabel='count', ylabel='Attack'>

# %%
sns.countplot(data=df,x= df['Attack'])
# Out:
# <Axes: xlabel='Attack', ylabel='count'>

# %%
df['Attack'].value_counts()
# Out:
# Attack
# vuln-scan        26246
# tcp-flood        21367
# Backdoor         21137
# none             14363
# syn-flood        13517
# cryptojacking    11596
# syn-stealth       7072
# Name: count, dtype: int64

# %%
df['Label'].value_counts()
# Out:
# Label
# attack    100935
# benign     14363
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x= df['Label'])
# Out:
# <Axes: xlabel='Label', ylabel='count'>

# %%
df['Attack'].value_counts().plot(kind='pie', autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data=df, x= df['State'])
# Out:
# <Axes: xlabel='State', ylabel='count'>

# %%
plt.hist(df['shunt_voltage'], bins=20)
# Out:
# (array([3.9740e+03, 4.8635e+04, 1.0159e+04, 6.7050e+03, 4.8440e+03,
#         6.3010e+03, 3.4610e+03, 1.9050e+03, 1.9700e+03, 1.3460e+03,
#         1.6050e+03, 2.9390e+03, 5.4730e+03, 6.6800e+03, 5.0940e+03,
#         2.7250e+03, 1.1340e+03, 2.9000e+02, 5.2000e+01, 6.0000e+00]),
#  array([ 417.  ,  456.85,  496.7 ,  536.55,  576.4 ,  616.25,  656.1 ,
#          695.95,  735.8 ,  775.65,  815.5 ,  855.35,  895.2 ,  935.05,
#          974.9 , 1014.75, 1054.6 , 1094.45, 1134.3 , 1174.15, 1214.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df['bus_voltage_V'], bins=20)
# Out:
# (array([3.3000e+01, 6.3100e+02, 2.6870e+03, 0.0000e+00, 8.2370e+03,
#         8.4320e+03, 4.1510e+03, 0.0000e+00, 1.9230e+03, 2.6420e+03,
#         2.8450e+03, 0.0000e+00, 6.3570e+03, 7.7860e+03, 7.2960e+03,
#         0.0000e+00, 3.4394e+04, 2.6394e+04, 1.4890e+03, 1.0000e+00]),
#  array([5.149, 5.152, 5.155, 5.158, 5.161, 5.164, 5.167, 5.17 , 5.173,
#         5.176, 5.179, 5.182, 5.185, 5.188, 5.191, 5.194, 5.197, 5.2  ,
#         5.203, 5.206, 5.209]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df['current_mA'], bins=20)
# Out:
# (array([4.0010e+03, 4.9084e+04, 1.0152e+04, 6.4850e+03, 4.9170e+03,
#         6.1420e+03, 3.3780e+03, 1.8840e+03, 1.9900e+03, 1.2630e+03,
#         1.6620e+03, 3.2020e+03, 5.5710e+03, 6.9060e+03, 5.0320e+03,
#         2.4170e+03, 9.2600e+02, 2.3600e+02, 4.4000e+01, 6.0000e+00]),
#  array([ 417.  ,  457.15,  497.3 ,  537.45,  577.6 ,  617.75,  657.9 ,
#          698.05,  738.2 ,  778.35,  818.5 ,  858.65,  898.8 ,  938.95,
#          979.1 , 1019.25, 1059.4 , 1099.55, 1139.7 , 1179.85, 1220.  ]),
#  <BarContainer object of 20 artists>)

# %%
sns.distplot(df['power_mW'])
# Out:
# /tmp/ipython-input-441177489.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['power_mW'])
# <Axes: xlabel='power_mW', ylabel='Density'>

# %%
sns.distplot(df['shunt_voltage'])
# Out:
# /tmp/ipython-input-2361781114.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['shunt_voltage'])
# <Axes: xlabel='shunt_voltage', ylabel='Density'>

# %%
sns.distplot(df['bus_voltage_V'])
# Out:
# /tmp/ipython-input-4035230578.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bus_voltage_V'])
# <Axes: xlabel='bus_voltage_V', ylabel='Density'>

# %%
sns.boxplot(df['shunt_voltage'])
# Out:
# <Axes: ylabel='shunt_voltage'>

# %%
sns.boxplot(df['bus_voltage_V'])
# Out:
# <Axes: ylabel='bus_voltage_V'>

# %%
sns.boxplot(df['current_mA'])
# Out:
# <Axes: ylabel='current_mA'>

# %%
sns.boxplot(df['power_mW'])
# Out:
# <Axes: ylabel='power_mW'>
