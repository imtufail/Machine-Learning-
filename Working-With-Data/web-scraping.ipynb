# %% [markdown]
# <a href="https://colab.research.google.com/github/imtufail/Machine-Learning-Contents/blob/main/Working-With-Data/web-scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage = requests.get('https://webscraper.io/test-sites/e-commerce/allinone', headers=headers).text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- Google Tag Manager -->
#   <script nonce="x1ykc95bvrvcgQHB95XUjxZABCi2jfm1">
#    (function (w, d, s, l, i) {
# 		w[l] = w[l] || [];
# 		w[l].push({
# 			'gtm.start':
# 				new Date().getTime(), event: 'gtm.js'
# 		});
# 		var f = d.getElementsByTagName(s)[0],
# 			j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : '';
# 		j.async = true;
# 		j.src =
# 			'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
# 		f.parentNode.insertBefore(j, f);
# 	})(window, document, 'script', 'dataLayer', 'GTM-NVFPDWB');
#   </script>
#   <!-- End Google Tag Manager -->
#   <title>
#    Allinone | Web Scraper Test Sites
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="web scraping,Web Scraper,Chrome extension,Crawling,Cross platform scraper" name="keywords"/>
# ...

# %%
for i in soup.find_all('p'):
    print(i.text)
# Out:
# Web Scraper
# Cloud Scraper
# Pricing
#
# 								Learn
#
#
#
# 			Welcome to WebScraper e-commerce site. You can use this site for training
# 			to learn how to use the Web Scraper. Items listed here are not for sale.
#
# Acer Aspire A515-51-5654, Black, 15.6", FHD, Core i5-8250U, 8GB DDR4, 256GB SSD, Windows 10 Home, ENG
#
# 9 reviews
#
#
#
#
#
# Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2
#
# 7 reviews
#
#
#
#
#
#
#
# Dell Latitude 5280, 12.5" HD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro
#
# 8 reviews
#
#
#
#
# Products
# Company
# Resources
# CONTACT US
# Copyright &copy 2025
# 					Web Scraper | All rights reserved

# %%
for i in soup.find_all('p'):
    print(i.text.strip())
# Out:
# Web Scraper
# Cloud Scraper
# Pricing
# Learn
# Welcome to WebScraper e-commerce site. You can use this site for training
# 			to learn how to use the Web Scraper. Items listed here are not for sale.
# Acer Aspire A515-51-5654, Black, 15.6", FHD, Core i5-8250U, 8GB DDR4, 256GB SSD, Windows 10 Home, ENG
# 9 reviews
#
# Black, 7" IPS, Quad-Core 1.2GHz, 8GB, Android 4.2
# 7 reviews
#
# Dell Latitude 5280, 12.5" HD, Core i5-7300U, 8GB, 256GB SSD, Windows 10 Pro
# 8 reviews
#
# Products
# Company
# Resources
# CONTACT US
# Copyright &copy 2025
# 					Web Scraper | All rights reserved

# %%
company = soup.find_all('div',class_='product-wrapper card-body')

# %%
len(company)
# Out:
# 3

# %%
from ast import Attribute
name =[]
price =[]
views =[]
numbers =[]

for i in company:
  name.append (i.find('a',class_="title").text.strip())
  price.append (i.find('span').text.strip())
  temp = i.find('p',class_='review-count').text.strip()
  # for j in temp:
  #   views.append(j.find('span', attrs={'itemprop':'eviewcount'}).text.strip())
  views.append(i.find('p',class_='review-count').text.strip())
  # numbers = [int(review.split()[0]) for review in views]
d = {'name':name, 'price':price,'views':views}
df= pd.DataFrame(d)
# df.to_csv('products.csv')
df
# Out:
#                 name     price      views
# 0  Acer Aspire A5...      $679  9 reviews
# 1     IdeaTab A3500L    $88.99  7 reviews
# 2   Dell Latitude...  $1102.66  8 reviews

# %%
df.shape
# Out:
# (3, 3)

# %%
numbers
# Out:
# [9, 7, 8]

# %%
views
# Out:
# ['9 reviews', '7 reviews', '8 reviews']
