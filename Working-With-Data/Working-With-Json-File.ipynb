# %% [markdown]
# <a href="https://colab.research.google.com/github/imtufail/Machine-Learning-Contents/blob/main/Working-With-Data/Working-With-Json-File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # How to deal with data in JSON format and SQL data

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download lkytal/trainjson
# Out:
# Dataset URL: https://www.kaggle.com/datasets/lkytal/trainjson
# License(s): CC-BY-NC-SA-4.0
# ...
#   0% 0.00/58.3M [00:00<?, ?B/s]
# 100% 58.3M/58.3M [00:00<00:00, 1.15GB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/trainjson.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()

# %%
import pandas as pd

# %%
df = pd.read_json('/content/train.json')

# %%
df
# Out:
#             id                                             band_1  \
# 0     dfd5f913  [-27.878360999999998, -27.15416, -28.668615, -...
# 1     e25388fd  [-12.242375, -14.920304999999999, -14.920363, ...
# 2     58b2aaa0  [-24.603676, -24.603714, -24.871029, -23.15277...
# 3     4cfc3a18  [-22.454607, -23.082819, -23.998013, -23.99805...
# 4     271f93f4  [-26.006956, -23.164886, -23.164886, -26.89116...
# ...        ...                                                ...
# 1599  04e11240  [-30.999878, -29.976866, -28.233906, -29.50732...
# 1600  c7d6f6f8  [-25.31155, -26.511555, -28.694487, -27.180115...
# 1601  bba1a0f1  [-18.141895, -18.141844, -19.01737, -19.701599...
# 1602  7f66bb44  [-22.455633, -25.794661, -26.954567, -22.83354...
# 1603  9d8f326c  [-19.909191, -20.678406, -20.208834, -18.42441...
#
#                                                  band_2 inc_angle  is_iceberg
# 0     [-27.154118, -29.537888, -31.0306, -32.190483,...   43.9239           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1604 entries, 0 to 1603
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1604 non-null   object
#  1   band_1      1604 non-null   object
#  2   band_2      1604 non-null   object
#  3   inc_angle   1604 non-null   object
#  4   is_iceberg  1604 non-null   int64
# dtypes: int64(1), object(4)
# memory usage: 62.8+ KB

# %%
df.describe()
# Out:
#         is_iceberg
# count  1604.000000
# mean      0.469451
# std       0.499222
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.shape
# Out:
# (1604, 5)

# %%
df.sample(10)
# Out:
#             id                                             band_1  \
# 544   09ecea99  [-14.006578, -15.370346, -15.029731, -12.63603...
# 473   9efee165  [-14.239149, -16.48278, -12.286911, -13.495303...
# 1243  4fe594cf  [-17.914183, -15.99753, -12.33362, -10.647278,...
# 1039  8dae8368  [-18.640596, -22.400478, -19.123419, -19.76718...
# 215   3bc5d385  [-19.637001, -19.917276, -22.754879, -23.80269...
# 603   a59605a2  [-19.522421, -17.127726, -17.127726, -19.38574...
# 360   2c039c2f  [-18.097994, -16.136719, -16.136719, -15.8639,...
# 68    79a6f286  [-17.480255, -18.581278, -19.064022, -18.34978...
# 1228  8f7628d7  [-18.423161, -17.971913999999998, -16.370056, ...
# 135   6706ea46  [-22.52327, -20.36145, -18.631905, -19.001574,...
#
#                                                  band_2 inc_angle  is_iceberg
# 544   [-24.006262, -22.306097, -24.244347, -24.00641...   40.4862           0
# 473   [-22.595293, -23.1682, -23.781647, -22.233479,...    33.634           1
# ...

# %%
df.duplicated().sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-13-1382667195.py in <cell line: 0>()
# ----> 1 df.duplicated().sum()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in duplicated(self, subset, keep)
#    6956         else:
#    6957             vals = (col.values for name, col in self.items() if name in subset)
# -> 6958             labels, shape = map(list, zip(*map(f, vals)))
#    6959
#    6960             ids = get_group_index(labels, tuple(shape), sort=False, xnull=False)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in f(vals)
#    6924
#    6925         def f(vals) -> tuple[np.ndarray, int]:
# -> 6926             labels, shape = algorithms.factorize(vals, size_hint=len(self))
#    6927             return labels.astype("i8", copy=False), len(shape)
#    6928
#
# ...

# %% [markdown]
# # SQL Data

# %%
# !pip install mysql.connector
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 89.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp311-cp311-linux_x86_64.whl size=247951 sha256=aae4e5f11a3ebc38927a4ab3e22d9299d593d64e12c78838338670ffc54affe3
#   Stored in directory: /root/.cache/pip/wheels/17/cd/ed/2d49e9bac69cf09382e4c7cc20a2511202b48324b87db26019
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

# %%
con = mysql.connector.connect(host='localhost', user='root', password='', database='test')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mysql/connector/network.py in open_connection(self)
#     508             self.sock.settimeout(self._connection_timeout)
# --> 509             self.sock.connect(sockaddr)
#     510         except IOError as err:
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# /tmp/ipython-input-21-2464338539.py in <cell line: 0>()
# ----> 1 con = mysql.connector.connect(host='localhost', user='root', password='', database='test')
#
# /usr/local/lib/python3.11/dist-packages/mysql/connector/__init__.py in connect(*args, **kwargs)
#     177         return CMySQLConnection(*args, **kwargs)
#     178     else:
# ...
